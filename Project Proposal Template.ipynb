# %% [markdown]
# # STOR 320: Introduction to Data Science
# ## 2024 Fall
# ## Project Proposal Group 9

# %% [markdown]
# ## Project Roles
#
# - **Creator:** Rita Luo , ritaluo@unc.edu, 730720015
# - **Interpreter:** Conor Jones, conjon@unc.edu, 730665579
# - **Interpreter:** Daniel Xu, danielxu@unc.edu, 730553878
# - **Deliverer:** FIRSTNAME LASTNAME, Email, PID

# %% [markdown]
# ## Datasets
#
# [Flights](https://www.kaggle.com/datasets/mahoora00135/flights)
# [Hotel booking demand](https://www.kaggle.com/datasets/jessemostipak/hotel-booking-demand)

# %% [markdown]
# ## Initial Questions (At least 10 questions)
#
# - **Question 1:** What is the relationship between the number of flights and the number of hotel bookings by month?
# - **Question 2:** Which is the best month to travel to avoid the peak season?
# - **Question 3:** What association between flight delays and hotel cancellations?
# - **Question 4:** How do weekday and weekend patterns differ for flights and hotel stays?
# - **Question 5:** How do countries compare on hotel cancellation rate?
# - **Question 6:** What is the relationship between the number of flights on a given day and the number of people staying at a hotel?
# - **Question 7:** When is the worst time of day to depart based on delay statistics?
# - **Question 8:** How do airlines compare on scheduling accuracy?
# - **Question 9:** What is the association between lead time and cancellation for hotels?
# - **Question 10:** which is the best month to travel to experience less of a delay?

# %%
import pandas as pd

# %%
flights_df = pd.read_csv('flights.csv')
hotels_df = pd.read_csv('hotel_bookings.csv')
pd.set_option('display.max_columns', None)

# %%
filtered_flights_df = flights_df.dropna()
filtered_flights_df
# Out:
#             id  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 0            0  2013      1    1     517.0             515        2.0
# 1            1  2013      1    1     533.0             529        4.0
# 2            2  2013      1    1     542.0             540        2.0
# 3            3  2013      1    1     544.0             545       -1.0
# 4            4  2013      1    1     554.0             600       -6.0
# ...        ...   ...    ...  ...       ...             ...        ...
# 336765  336765  2013      9   30    2240.0            2245       -5.0
# 336766  336766  2013      9   30    2240.0            2250      -10.0
# 336767  336767  2013      9   30    2241.0            2246       -5.0
# 336768  336768  2013      9   30    2307.0            2255       12.0
# 336769  336769  2013      9   30    2349.0            2359      -10.0
#
#         arr_time  sched_arr_time  arr_delay carrier  flight tailnum origin  \
# ...

# %%
usa_hotels = hotels_df[hotels_df['country'] == 'USA']
usa_hotels
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 12      Resort Hotel            0         68               2015
# 59      Resort Hotel            0         14               2015
# 65      Resort Hotel            0         10               2015
# 92      Resort Hotel            0          9               2015
# 162     Resort Hotel            0         51               2015
# ...              ...          ...        ...                ...
# 119104    City Hotel            0         15               2017
# 119224    City Hotel            0         83               2017
# 119234    City Hotel            0        189               2017
# 119325    City Hotel            0        147               2017
# 119358    City Hotel            0        135               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 12                   July                        27
# 59                   July                        27
# ...
